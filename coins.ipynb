# %%
# !pip install ultralytics

# %%
# %cd /content/drive/MyDrive/Menna
# Out:
# /content/drive/MyDrive/Menna

# %%
# !unzip ./dataset.zip

# %%
# !yolo task=detect mode=train data=/content/coins.yaml epochs=150 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 8.43MB/s]
# Ultralytics YOLOv8.0.180 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train  model=/content/drive/MyDrive/Menna/runs/detect/train/weights/last.pt data=/content/coins.yaml  resume=true
# Out:
# Ultralytics YOLOv8.0.180 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
